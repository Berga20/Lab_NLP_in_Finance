# %% [markdown]
# # Python LAB - Natural Language Processing in Finance [2.1]

# %% [markdown]
# ## 0 - Packages

# %%
# %pip install nltk
# %pip install bs4
# %pip install htmldate
# %pip install selenium
# %pip install newspaper3k
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/marco/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk) (4.66.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /Users/marco/Library/Python/3.9/lib/python/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->bs4) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: htmldate in /Users/marco/Library/Python/3.9/lib/python/site-packages (1.7.0)
# Requirement already satisfied: dateparser>=1.1.2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from htmldate) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from htmldate) (2.8.2)
# Requirement already satisfied: lxml<6,>=4.9.4 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from htmldate) (5.1.0)
# Requirement already satisfied: charset-normalizer>=3.3.2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from htmldate) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from htmldate) (2.2.0)
# Requirement already satisfied: pytz in /Users/marco/Library/Python/3.9/lib/python/site-packages (from dateparser>=1.1.2->htmldate) (2023.4)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from dateparser>=1.1.2->htmldate) (2023.12.25)
# Requirement already satisfied: tzlocal in /Users/marco/Library/Python/3.9/lib/python/site-packages (from dateparser>=1.1.2->htmldate) (5.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->htmldate) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in /Users/marco/Library/Python/3.9/lib/python/site-packages (4.17.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.0)
# Requirement already satisfied: trio~=0.17 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=20.1.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: newspaper3k in /Users/marco/Library/Python/3.9/lib/python/site-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (4.12.3)
# Requirement already satisfied: Pillow>=3.3.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (10.2.0)
# Requirement already satisfied: PyYAML>=3.11 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (6.0.1)
# Requirement already satisfied: cssselect>=0.9.2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (5.1.0)
# Requirement already satisfied: nltk>=3.2.1 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (2.31.0)
# Requirement already satisfied: feedparser>=5.2.1 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (5.1.1)
# Requirement already satisfied: feedfinder2>=0.0.4 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tinysegmenter==0.3 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Requirement already satisfied: sgmllib3k in /Users/marco/Library/Python/3.9/lib/python/site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk>=3.2.1->newspaper3k) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk>=3.2.1->newspaper3k) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/marco/Library/Python/3.9/lib/python/site-packages (from nltk>=3.2.1->newspaper3k) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from requests>=2.10.0->newspaper3k) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from requests>=2.10.0->newspaper3k) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from requests>=2.10.0->newspaper3k) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from requests>=2.10.0->newspaper3k) (2024.2.2)
# Requirement already satisfied: requests-file>=1.4 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from tldextract>=2.0.1->newspaper3k) (2.0.0)
# Requirement already satisfied: filelock>=3.0.8 in /Users/marco/Library/Python/3.9/lib/python/site-packages (from tldextract>=2.0.1->newspaper3k) (3.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import time
import nltk
import warnings
warnings.filterwarnings('ignore')

from htmldate import find_date
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newspaper import Article

from selenium import webdriver
from selenium.webdriver.common.by import By
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.downloader.download('vader_lexicon')
from htmldate import find_date
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/marco/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## 1 - Starting the Webdriver

# %% [markdown]
# In order for the webscraping function to work you need to install in you computer the webdriver. Depending on the computer you are using and the version of the browser you have (I suggest Chrome, but it works also on other browsers) you will need to download it and put it in the same folder you are working on.
#
# Take a look at the following links in case you are interested:
# * [How to install the webdriver](https://www.youtube.com/watch?v=2WVxzRD6Ds4)
# * [Chromedriver download](https://chromedriver.chromium.org/)

# %%
driver = webdriver.Chrome()
# Out:
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event): operation timed out

# %% [markdown]
# ## 2 - Collecting News Data

# %% [markdown]
# ### 2.1 News-collection Function

# %%
def get_newslinks(company, page_number):
    """
    :param company: name of company to scrape articles for
    :param page_number: page number on news website to iterate over 

    :return: list of articles URLs
    """
    
    url = f"https://uk.investing.com/equities/{company}-news/{page_number}"
    driver.get(url)
    
    old_position = 0
    new_position = None

    while new_position != old_position:

        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                " window.pageYOffset : (document.documentElement ||"
                " document.body.parentNode || document.body);"))

        time.sleep(1)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))

        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                " window.pageYOffset : (document.documentElement ||"
                " document.body.parentNode || document.body);"))
        
    cleaned_links = []

    # Iteration on the page
    for art_n in range(1,11): 
        article = driver.find_element(By.XPATH, value = f'/html/body/div[1]/div[2]/div[2]/div[2]/div[1]/div[2]/ul/li[{art_n}]/article/div')
        article_html = article.get_attribute('innerHTML')
        soup = BeautifulSoup(article_html, "lxml")
        for link in soup.find_all('a'): 
            # Getting href
            partial_link = link.get('href')
            if partial_link is not None:
                if 'https' in partial_link: 
                    cleaned_links.append(partial_link)
                # Solving issue with internal links
                elif partial_link[0] == '/': 
                    cleaned_links.append('https://uk.investing.com/'+partial_link) 

    return np.unique(cleaned_links)

# %% [markdown]
# ### 2.2 News Collection

# %%
all_company_urls = []
for page in range(1,3): # here insert the number of page you want to scrape
    results = get_newslinks('royal-dutch-shell-a-shr', page)
    all_company_urls.extend(results)

driver.quit()

# %%
all_company_urls
# Out:
# ['https://uk.investing.com//news/commodities-news/shell-agrees-to-sell-its-nigeria-onshore-oil-and-gas-business-3298980',
#  'https://uk.investing.com//news/stock-market-news/european-stocks-weaken-ahead-of-boe-eurozone-cpi-deutsche-bank-shines-3319459',
#  'https://uk.investing.com//news/stock-market-news/ftse-100-live-stocks-in-the-green-supported-by-oil-majors-3314447',
#  'https://uk.investing.com//news/stock-market-news/labour-would-unashamedly-champion-city-says-shadow-chancellor-3317588',
#  'https://uk.investing.com//news/stock-market-news/london-midday-ftse-pares-gains-amid-diverging-fortunes-for-next-jd-sports-3286775',
#  'https://uk.investing.com//news/stock-market-news/uk-shares-lower-at-close-of-trade-investingcom-united-kingdom-100-down-051-2671467#comments',
#  'https://uk.investing.com//news/stock-market-news/uk-shares-lower-at-close-of-trade-investingcom-united-kingdom-100-down-294-2681227']

# %% [markdown]
# ## 3 - Sentiment Analysis

# %%
ticker = 'SHEL'
# DataFrame
article_sentiments = pd.DataFrame({'ticker':[],
                                'publish_date':[],
                                'title': [],
                                'body_text': [],
                                'url':[],
                                'neg':[],
                                'neu':[], 
                                'pos':[], 
                                'compound':[]})
# Loop over articles
for link in all_company_urls:
      article = Article(link)
      article.download()
      
      try:
          article.parse()
          text = article.text

      except: 
          print("I didn't get this")
          continue
        
      sid = SentimentIntensityAnalyzer()
      # Get sentiment scores
      polarity = sid.polarity_scores(text)

      tmpdic = {'ticker': ticker, 'publish_date': find_date(link), 'title': article.title, 'body_text': article.text, 'url': link}
      tmpdic.update(polarity)

      article_sentiments= article_sentiments.append(pd.DataFrame(tmpdic, index=[0]))
      article_sentiments.reset_index(drop=True, inplace=True)

# %%
article_sentiments
# Out:
#    ticker publish_date                                              title  \
# 0    SHEL   2024-01-16  Shell to exit Nigeria's troubled onshore oil a...
# 1    SHEL   2024-02-01  European stocks weaken ahead of BOE, eurozone ...
# 2    SHEL   2024-01-29  FTSE 100 Live: Stocks in the green supported b...
# 3    SHEL   2024-01-31  Labour would 'unashamedly champion' City, says...
# 4    SHEL   2024-01-04  London midday: FTSE pares gains amid diverging...
# 5    SHEL   2023-11-27  London open: Stocks edge down on weak Asian cu...
# 6    SHEL   2024-02-14  Oil majors seek arbitration in gas dispute wit...
# 7    SHEL   2024-02-05  Shell agrees to develop Nigeria gas field for ...
# 8    SHEL   2024-02-13  Shell quits Iraqi petrochemicals plant talks B...
# 9    SHEL   2023-12-12  UK firms pause China investment decisions as g...
# 10   SHEL   2023-08-24  Shell taps Goldman Sachs to explore Singapore ...
# 11   SHEL   2023-09-05  Exclusive-Shell, Trinidad weigh Venezuela's na...
# 12   SHEL   2023-11-08  FTSE 100 sees minor decline amidst robust reta...
# 13   SHEL   2023-11-08  FTSE 100 sees minor decline amidst robust reta...
# 14   SHEL   2023-09-22  JPMorgan advocates for energy stocks, anticipa...
# 15   SHEL   2023-08-15  Peering Into Shell's Recent Short Interest By ...
# 16   SHEL   2023-10-11  Shell Amsterdam shares hit highest since 2001 ...
# 17   SHEL   2023-09-19  Shell opens its largest EV charging station gl...
# 18   SHEL   2023-09-21  Shell seeks partners for renewable assets in I...
# 19   SHEL   2023-09-01  Shell sells home energy business in UK, German...
# 20   SHEL   2023-09-07  Shell puts Germany's sonnen on the block -repo...
# 21   SHEL   2022-07-05  Natural Gas Soars 700%, Becoming Driving Force...
# 22   SHEL   2022-07-05  Natural Gas Soars 700%, Becoming Driving Force...
# 23   SHEL   2022-05-05  Shell Earnings, Revenue beat in Q1 By Investin...
# 24   SHEL   2022-07-28  Shell Earnings, Revenue beat in Q2 By Investin...
# 25   SHEL   2022-07-28  Shell Earnings, Revenue beat in Q2 By Investin...
# 26   SHEL   2023-04-06  Shell projects strong gas trading in first qua...
# 27   SHEL   2023-04-06  Shell projects strong gas trading in first qua...
