# %% [markdown]
# # Python LAB - Natural Language Processing in Finance [2.1]

# %% [markdown]
# ## 0 - Packages

# %%
import pandas as pd
import numpy as np
import time
import nltk
import warnings
warnings.filterwarnings('ignore')

from htmldate import find_date
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newspaper import Article

from selenium import webdriver
from selenium.webdriver.common.by import By
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.downloader.download('vader_lexicon')
from htmldate import find_date

from newspaper import Article
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/marco/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## 1 - Starting the Webdriver

# %% [markdown]
# In order for the webscraping function to work you need to install in you computer the webdriver. Depending on the computer you are using and the version of the browser you have (I suggest Chrome, but it works also on other browsers) you will need to download it and put it in the same folder you are working on.
#
# Take a look at the following links in case you are interested:
# * [How to install the webdriver](https://www.youtube.com/watch?v=2WVxzRD6Ds4)
# * [Chromedriver download](https://chromedriver.chromium.org/)

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ## 2 - Collecting News Data

# %% [markdown]
# ### 2.1 News-collection Function

# %%
def get_newslinks(company, page_number):
    """For a given URL, scroll to relevant section to load appropriate HTML into driver,
    iterate through all articles on page and append article URLs to a list

    :param company: name of company to scrape articles for
    :param page_number: page number on news website to iterate over 

    :return: list of articles URLs
    """
    
    url = f"https://uk.investing.com/equities/{company}-news/{page_number}"
    driver.get(url)
    
    old_position = 0
    new_position = None

    while new_position != old_position:
        # Get old scroll position
        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                " window.pageYOffset : (document.documentElement ||"
                " document.body.parentNode || document.body);"))
        # Sleep and Scroll
        time.sleep(1)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))
        # Get new position
        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                " window.pageYOffset : (document.documentElement ||"
                " document.body.parentNode || document.body);"))
        
    cleaned_links = []

    # Iterate through all the articles on the page
    for art_n in range(1,11): 
        article = driver.find_element(By.XPATH, value = f'/html/body/div[1]/div[2]/div[2]/div[2]/div[1]/div[2]/ul/li[{art_n}]/article/div')
        article_html = article.get_attribute('innerHTML')
        soup = BeautifulSoup(article_html, "lxml")
        for link in soup.find_all('a'): 
            # Get the href
            partial_link = link.get('href')
            if partial_link is not None:
                if 'https' in partial_link: 
                    cleaned_links.append(partial_link)
                # Some links are 'internal' to the page and don't have https in them. The web page must be appended to these links
                elif partial_link[0] == '/': 
                    cleaned_links.append('https://uk.investing.com/'+partial_link) 

    return np.unique(cleaned_links)

# %% [markdown]
# ### 2.2 News Collection

# %%
all_company_urls = []
for page in range(1,5):
    results = get_newslinks('oracle-corp', page)
    all_company_urls.extend(results)

driver.quit()

# %%
all_company_urls
# Out:
# ['https://uk.investing.com//news/stock-market-news/1000-invested-in-this-stock-20-years-ago-would-be-worth-8500-today-3330008',
#  'https://uk.investing.com//news/stock-market-news/90s-tech-titans-are-outshining-magnificent-seven--analyst-tells-why-market-is-going-gaga-over-them-3312571',
#  'https://uk.investing.com//news/stock-market-news/north-carolina-adopts-oracle-cloud-erp-for-financial-management-93CH-3333821',
#  'https://uk.investing.com//news/stock-market-news/oracle-named-a-leader-in-the-idc-marketscape-us-ehr-vendor-assessment-93CH-3329846',
#  'https://uk.investing.com//news/stock-market-news/orc--analyzing-orchid-island-caps-short-interest-3312894',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3326567_news_8',
#  'https://uk.investing.com//news/economy/as-davos-crowd-gathers-governments-urged-to-rein-in-billionaire-class-3298033',
#  'https://uk.investing.com//news/stock-market-news/frances-ovhcloud-firstquarter-sales-jump-12-on-europe-boost-3294590',
#  'https://uk.investing.com//news/stock-market-news/hollywood-power-play-david-ellison-aims-to-transform-paramount-global-under-skydance-leadership-3311645',
#  'https://uk.investing.com//news/stock-market-news/if-you-invested-1000-in-this-stock-5-years-ago-you-would-have-2200-today-3308292',
#  'https://uk.investing.com//news/stock-market-news/musk-bezos-buffett-get-richer-rest-of-world-gets-poorer-heres-a-look-at-wealth-inequality-over-last-3-years-3301838',
#  'https://uk.investing.com//news/stock-market-news/oracle-launches-oci-generative-ai-service-with-advanced-language-models-93CH-3307442',
#  'https://uk.investing.com//news/stock-market-news/pro-research-wall-street-dives-into-oracles-cloud-transition-93CH-3305829',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3304371_news_6',
#  'https://uk.investing.com//news/stock-market-news/heres-how-much-you-would-have-made-owning-oracle-stock-in-the-last-20-years-3280236',
#  'https://uk.investing.com//news/stock-market-news/heres-how-much-you-would-have-made-owning-oracle-stock-in-the-last-20-years-3294023',
#  'https://uk.investing.com//news/stock-market-news/how-is-the-market-feeling-about-oracle-3292693',
#  'https://uk.investing.com//news/stock-market-news/oracle-zoom-video-booz-allen-hamilton-and-a-data-storage-company-on-cnbcs-final-trades-3278960',
#  'https://uk.investing.com//news/stock-market-news/orcl--analyzing-oracles-short-interest-3277822',
#  'https://uk.investing.com//news/stock-market-news/worlds-top-10-richest-people-gained-more-wealth-in-2023-than-walmarts-total-value-how-elon-musk-jeff-bezos-and-others-fared-3284555',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3275490_news_10',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3278863_news_8',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3283962_news_5',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3290089_news_3',
#  'https://uk.investing.com//news/stock-market-news/4-oracle-analysts-dive-into-q2-print-why-last-quarters-revenue-drag-persisted-3267356',
#  'https://uk.investing.com//news/stock-market-news/bernstein-says-oracle-growth-pains-continue-as-it-strives-to-meet-demand-432SI-3267392',
#  'https://uk.investing.com//news/stock-market-news/dow-jumps-over-100-points-oracle-posts-mixed-q2-results-3267332',
#  'https://uk.investing.com//news/stock-market-news/earnings-call-oracle-sees-robust-cloud-growth-plans-100-new-data-centers-93CH-3268566',
#  'https://uk.investing.com//news/stock-market-news/how-to-earn-500-a-month-from-oracle-stock-after-q2-earnings-results-3267209',
#  'https://uk.investing.com//news/stock-market-news/investor-sentiment-rises-following-inflation-report-fed-decision-in-focus-3267900',
#  'https://uk.investing.com//news/stock-market-news/midday-movers-oracle-moderna-and-more-432SI-3267297',
#  'https://uk.investing.com//news/stock-market-news/us-futures-steady-ahead-of-november-inflation-data-3266774',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3268157_news_3',
#  'https://uk.investing.com//pro/offers/breaking-news-offer?referral=3269275_news_1']

# %% [markdown]
# ## 3 - Sentiment Analysis

# %%
# stock ticker
ticker = 'ORCL'
# Create a DataFrame to populate while iterating
article_sentiments = pd.DataFrame({'ticker':[],
                                'publish_date':[],
                                'title': [],
                                'body_text': [],
                                'url':[],
                                'neg':[],
                                'neu':[], 
                                'pos':[], 
                                'compound':[]})
# Loop over all the articles
for link in all_company_urls:
      article = Article(link)
      article.download()
      
      try:
          article.parse()
          text = article.text

      except: 
          print("I didn't get this")
          continue

      # Initialise sentiment analyser    
      sid = SentimentIntensityAnalyzer()
      # Get positive, negative, neutral and compound scores
      polarity = sid.polarity_scores(text)

      tmpdic = {'ticker': ticker, 'publish_date': find_date(link), 'title': article.title, 'body_text': article.text, 'url': link}
      # Update ticker with the new entry polarity
      tmpdic.update(polarity)
      # tmpdic now has all keys and values needed to populate the DataFrame
      article_sentiments= article_sentiments.append(pd.DataFrame(tmpdic, index=[0]))
      article_sentiments.reset_index(drop=True, inplace=True)

# %%
article_sentiments
# Out:
#    ticker publish_date                                              title  \
# 0    ORCL   2024-02-08  $1000 Invested In This Stock 20 Years Ago Woul...
# 1    ORCL   2024-01-26  90's Tech Titans Are Outshining 'Magnificent S...
# 2    ORCL   2024-02-12  North Carolina adopts Oracle Cloud ERP for fin...
# 3    ORCL   2024-02-08  Oracle Named a Leader in the IDC MarketScape U...
# 4    ORCL   2024-01-26  Analyzing Orchid Island Cap's Short Interest B...
# 5    ORCL   2024-01-01                                       InvestingPro
# 6    ORCL   2024-01-15  As Davos crowd gathers, governments urged to r...
# 7    ORCL   2024-01-11  France's OVHcloud first-quarter sales rise 12%...
# 8    ORCL   2024-01-25  Hollywood Power Play: David Ellison Aims to Tr...
# 9    ORCL   2024-01-23  If You Invested $1000 In This Stock 5 Years Ag...
# 10   ORCL   2024-01-17  Musk, Bezos, Buffett Get Richer, Rest Of World...
# 11   ORCL   2024-01-23  Oracle launches OCI Generative AI service with...
# 12   ORCL   2024-01-22  Pro Research: Wall Street dives into Oracle's ...
# 13   ORCL   2024-01-01                                       InvestingPro
# 14   ORCL   2023-12-25  Here's How Much You Would Have Made Owning Ora...
# 15   ORCL   2024-01-10  Here's How Much You Would Have Made Owning Ora...
# 16   ORCL   2024-01-09  How Is The Market Feeling About Oracle? By Ben...
# 17   ORCL   2023-12-22  Oracle, Zoom Video, Booz Allen Hamilton And A ...
# 18   ORCL   2023-12-21      Analyzing Oracle's Short Interest By Benzinga
# 19   ORCL   2024-01-02  World's Top 10 Richest People Gained More Weal...
# 20   ORCL   2024-01-01                                       InvestingPro
# 21   ORCL   2024-01-01                                       InvestingPro
# 22   ORCL   2024-01-01                                       InvestingPro
# 23   ORCL   2024-01-01                                       InvestingPro
# 24   ORCL   2023-12-12  4 Oracle Analysts Dive Into Q2 Print: Why Last...
# 25   ORCL   2023-12-12  Bernstein says Oracle growth pains continue as...
# 26   ORCL   2023-12-12  Dow Jumps Over 100 Points; Oracle Posts Mixed ...
# 27   ORCL   2023-12-13  Earnings call: Oracle sees robust cloud growth...
# 28   ORCL   2023-12-12  How To Earn $500 A Month From Oracle Stock Aft...
# 29   ORCL   2023-12-13  Investor Sentiment Rises Following Inflation R...
# 30   ORCL   2023-12-12  Midday movers: Oracle, Moderna and more By Inv...
# 31   ORCL   2023-12-12  Stock Market Today: Dow ends higher as inflati...
# 32   ORCL   2024-01-01                                       InvestingPro
# 33   ORCL   2024-01-01                                       InvestingPro
#
#                                             body_text  \
# 0   Published Feb 08, 2024 15:30 Updated Feb 08, 2...
# 1   Published Jan 26, 2024 12:12 Updated Jan 26, 2...
# 2   Published Feb 12, 2024 13:04\n\n© Reuters\n\nO...
# 3   Oracle recognized for AI automation, value del...
# 4   Published Jan 26, 2024 14:30 Updated Jan 26, 2...
# 5
# 6   Published Jan 15, 2024 00:19 Updated Jan 15, 2...
# 7   Published Jan 11, 2024 06:47 Updated Jan 11, 2...
# 8   Published Jan 25, 2024 18:56 Updated Jan 25, 2...
# 9   Published Jan 23, 2024 18:37 Updated Jan 23, 2...
# 10  Published Jan 17, 2024 17:11 Updated Jan 17, 2...
# 11  Published Jan 23, 2024 11:00\n\n© Reuters.\n\n...
# 12  Published Jan 22, 2024 10:18\n\n© Reuters.\n\n...
# 13
# 14  Published Dec 25, 2023 19:01 Updated Dec 25, 2...
# 15  Published Jan 10, 2024 15:00 Updated Jan 10, 2...
# 16  Published Jan 09, 2024 20:45 Updated Jan 09, 2...
# 17  Published Dec 22, 2023 13:39 Updated Dec 22, 2...
# 18  Published Dec 21, 2023 13:30 Updated Dec 21, 2...
# 19  Published Jan 02, 2024 16:06 Updated Jan 02, 2...
# 20
# 21
# 22
# 23
# 24  Published Dec 12, 2023 17:15 Updated Dec 12, 2...
# 25  Published Dec 12, 2023 19:32\n\n© Reuters\n\nO...
# 26  Published Dec 12, 2023 16:58 Updated Dec 12, 2...
# 27  Published Dec 13, 2023 15:28\n\n© Reuters.\n\n...
# 28  Published Dec 12, 2023 14:40 Updated Dec 12, 2...
# 29  Published Dec 13, 2023 07:25 Updated Dec 13, 2...
# 30  Published Dec 12, 2023 17:20\n\nORCL -0.14% Ad...
# 31  Published Dec 12, 2023 12:48 Updated Dec 12, 2...
# 32
# 33
#
#                                                   url    neg    neu    pos  \
# 0   https://uk.investing.com//news/stock-market-ne...  0.000  0.952  0.048
# 1   https://uk.investing.com//news/stock-market-ne...  0.011  0.871  0.118
# 2   https://uk.investing.com//news/stock-market-ne...  0.014  0.905  0.081
# 3   https://uk.investing.com//news/stock-market-ne...  0.017  0.848  0.135
# 4   https://uk.investing.com//news/stock-market-ne...  0.012  0.825  0.164
# 5   https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 6   https://uk.investing.com//news/economy/as-davo...  0.034  0.836  0.130
# 7   https://uk.investing.com//news/stock-market-ne...  0.013  0.881  0.106
# 8   https://uk.investing.com//news/stock-market-ne...  0.041  0.872  0.088
# 9   https://uk.investing.com//news/stock-market-ne...  0.000  0.962  0.038
# 10  https://uk.investing.com//news/stock-market-ne...  0.045  0.776  0.179
# 11  https://uk.investing.com//news/stock-market-ne...  0.000  0.907  0.093
# 12  https://uk.investing.com//news/stock-market-ne...  0.029  0.827  0.145
# 13  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 14  https://uk.investing.com//news/stock-market-ne...  0.000  0.962  0.038
# 15  https://uk.investing.com//news/stock-market-ne...  0.000  0.962  0.038
# 16  https://uk.investing.com//news/stock-market-ne...  0.012  0.821  0.167
# 17  https://uk.investing.com//news/stock-market-ne...  0.017  0.913  0.069
# 18  https://uk.investing.com//news/stock-market-ne...  0.012  0.820  0.168
# 19  https://uk.investing.com//news/stock-market-ne...  0.008  0.790  0.202
# 20  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 21  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 22  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 23  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 24  https://uk.investing.com//news/stock-market-ne...  0.026  0.868  0.106
# 25  https://uk.investing.com//news/stock-market-ne...  0.028  0.846  0.126
# 26  https://uk.investing.com//news/stock-market-ne...  0.023  0.868  0.109
# 27  https://uk.investing.com//news/stock-market-ne...  0.033  0.847  0.120
# 28  https://uk.investing.com//news/stock-market-ne...  0.000  0.950  0.050
# 29  https://uk.investing.com//news/stock-market-ne...  0.094  0.855  0.052
# 30  https://uk.investing.com//news/stock-market-ne...  0.042  0.910  0.048
# 31  https://uk.investing.com//news/stock-market-ne...  0.065  0.859  0.076
# 32  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
# 33  https://uk.investing.com//pro/offers/breaking-...  0.000  0.000  0.000
#
#     compound
# 0     0.7717
# 1     0.9962
# 2     0.9647
# 3     0.9966
# 4     0.9965
# 5     0.0000
# 6     0.9924
# 7     0.9744
# 8     0.9486
# 9     0.7003
# 10    0.9979
# 11    0.9694
# 12    0.9994
# 13    0.0000
# 14    0.7003
# 15    0.7003
# 16    0.9965
# 17    0.9493
# 18    0.9965
# 19    0.9993
# 20    0.0000
# 21    0.0000
# 22    0.0000
# 23    0.0000
# 24    0.9926
# 25    0.9788
# 26    0.9952
# 27    1.0000
# 28    0.9287
# 29   -0.9556
# 30    0.2023
# 31    0.3495
# 32    0.0000
# 33    0.0000

# %% [markdown]
# ## 4 - Storing Dataframe

# %%
article_sentiments.to_csv("Oracle_articles.csv", sep=',', encoding='utf-8', header=True)

with open('nvidia_urls_20210105.txt', 'w') as f:
    for link in all_company_urls: 
        f.write("%s\n" % link)
